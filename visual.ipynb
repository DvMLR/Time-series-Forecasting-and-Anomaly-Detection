# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
preds = np.load('./results/informer_custom_ftM_sl60_ll30_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_1/pred.npy')
trues = np.load('./results/informer_custom_ftM_sl60_ll30_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_1/true.npy')
metrics = np.load('./results/informer_custom_ftM_sl60_ll30_pl30_dm512_nh8_el2_dl1_df2048_atprob_fc5_ebtimeF_dtTrue_mxTrue_test_1/metrics.npy')
# [samples, pred_len, dimensions]
preds.shape, trues.shape
# Out:
# ((44800, 30, 3), (44800, 30, 3))

# %%
plt.figure()
plt.plot(trues[0,:,0], label='GroundTruth')
plt.plot(preds[0,:,0], label='Prediction')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(trues[30,:,0], label='GroundTruth')
plt.plot(preds[30,:,0], label='Prediction')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(trues[10000,:,0], label='GroundTruth')
plt.plot(preds[10000,:,0], label='Prediction')
plt.legend()
plt.show()

# %%
ejemplotest = trues.reshape(1344000 ,3)
ejemplotest1 = preds.reshape(1344000 ,3)
#ejemplotest = ejemplotest[0:1000]
#ejemplotest1 = ejemplotest1[0:1000]

# %%
sns.set(rc={'figure.figsize':(20,10)})

# %%
plt.figure()
plt.plot(ejemplotest[:,0],'r', label="Real",linewidth=1 )
plt.plot(ejemplotest1[:,0],'b', label="Predicción", linewidth=0.5)
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure()
plt.plot(ejemplotest[:,1],'r', label="Real",linewidth=1 )
plt.plot(ejemplotest1[:,1],'b', label="Predicción", linewidth=0.5)
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure()
plt.plot(ejemplotest[:,2],'r', label="Real")#,linewidth=1 )
plt.plot(ejemplotest1[:,2],'b', label="Predicción")#, linewidth=0.5)
plt.legend(loc='upper left')
plt.show()
